# %%
from src.AAR import RidgeRegressor, AAR
from src.utils import read_file
from sklearn.model_selection import train_test_split

DATASET_PATH = "./dataset/data.csv"
df = read_file(DATASET_PATH, None)

x_cols = ['Sensor_1', 'Sensor_2', 'Sensor_3', 'Sensor_4']
y_cols = ['Measurement']

df_train, df_test = train_test_split(df, test_size = 0.2, random_state = 42)

x_train, y_train = df_train[x_cols].values, df_train[y_cols].values
x_test, y_test = df_test[x_cols].values, df_test[y_cols].values

model = RidgeRegressor(input_dims = 4, gamma = 0.01)
model.fit(x_train, y_train)
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
y_pred = model.predict(x_test)

plt.plot(y_pred, 'bo-', label = "prediction")
plt.plot(y_test, "ro-", label = "actual")
plt.xlabel("data point")
plt.ylabel("Measurement")
plt.legend()
plt.show()

# %%
model = AAR(input_dims = 4, gamma = 0.01)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

plt.plot(y_pred, 'bo-', label = "prediction")
plt.plot(y_test, "ro-", label = "actual")
plt.xlabel("data point")
plt.ylabel("Measurement")
plt.legend()
plt.show()
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]

# %%
from src.FLH import FLH
from src.AAR import AAR
model = FLH(alpha = 0.1, gamma = 0.01, input_dims = 4)
y_pred = model.fit_predict(x_test, y_test)

plt.plot(y_pred, 'bo-', label = "prediction")
plt.plot(y_test, "ro-", label = "actual")
plt.xlabel("data point")
plt.ylabel("Measurement")
plt.legend()
plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
